# %% [markdown]
# # Reproducing Published ETVs / TTVs

# %% [markdown]
# ## ETVs in `2013ApJ...768...33R`
#
# [Triple-star Candidates among the Kepler Binaries](https://ui.adsabs.harvard.edu/abs/2013ApJ...768...33R/abstract)
#
# - Failed for most eclipes with depth > 10%, the lone exception is the secondary eclipse for KIC 6525196 / TIC 137757776
#   - failure here means the eclipse timing appears to have no significant variation.
# - Significantly fewer data points for fitting individual eclipses (~10)

# %% [markdown]
# ### KIC 6545018 / TIC 169820995: failed for both primary (~ 27% depth) and secondary (~ 22% depth)
#
# Paper: (x, time-span: ~1300 d ; y, O-C in kilosecs. Amplitude ~1000s, or 16min)
#
# ![image.png](attachment:1d021faf-0e03-4aaf-9992-a591a2a1006d.png)
#
#
# Reproduction (Kepler data):
#
# ![image.png](attachment:6608b12a-820b-4aa8-91c0-00700d26aa58.png)

# %% [markdown]
# ### KIC 6525196 / TIC 137757776 : failed for primary (~ 17% depth); okay for secondary  (~ 15% depth)
#
# Paper: (x, time-span: ~1300 d ; y, O-C in kilosecs. Amplitude ~600s, or 10min)
#
# ![image.png](attachment:917a560c-b85d-45d0-9b1c-0f1d1ef71c07.png)
#
# Reproduction (Kepler data):
#
# ![image.png](attachment:b82ec75b-f124-48ec-aadf-b070ea3f13ea.png)
#
# TESS data: possibly similar to Kepler result (time span is too short)

# %% [markdown]
# ### KIC 9714358 / TIC 270618498: failed for primary (~ 20% depth); okay for secondary (~ 1.5% depth)
#
# Paper: (x, time-span: ~1300 d ; y, O-C in kilosecs. Amplitude ~2000s, or 33min)
#
# ![image.png](attachment:87df97f0-d545-4c09-9607-5d7195574ffe.png)
#
#
# Reproduction (Kepler data):
#
# ![image.png](attachment:7a1913b3-9e1a-46b9-91de-de12d69fbdaa.png)
#
# TESS data: not done (only 30min cadence LCs from CDIPS)

# %% [markdown]
# ### KIC 7289157 / TIC 270782003 : okay both primary (~ 6% depth) and secondary (~ 0.8% depth) [*]
#
# Paper: (x, time-span: ~1300 d ; y, O-C in kilosecs. Amplitude ~1800s, or 30min)
#
# ![image.png](attachment:a76569a5-3de8-45b7-8b47-d2984e4cbb0d.png)
#
# Reproduction (Kepler data):
#
# ![image.png](attachment:d596e221-d396-46f8-a172-70ad93d3f840.png)
#
# [*] The reproduced ETV for secondary eclipses appear to have some longer-term (possibly 1000+ days) variability. Unsure if it is in the paper.
#
# TESS data: the QLP lightcurves from 6 sectors do not show any eclipse. Neither does ZTF data

# %% [markdown]
# ### KIC 4909707 / TIC 121119758 : okay both primary (~ 3% depth) and secondary (~ 2% depth)
#
# Paper: (x, time-span: ~1300 d ; y, O-C in kilosecs. Amplitude ~1000s, or 16min)
#
# ![image.png](attachment:ae94f72d-497e-49b5-96de-abfaf2b65276.png)
#
#
# Reproduction (Kepler data):
#
# ![image.png](attachment:57967692-3b24-4112-badd-41de9c2be753.png)
#
#
# Reproduction (TESS data, much shoter time span, comparable to Kepler data):
#
# ![image.png](attachment:462041ac-e3a5-4067-b7b1-ae0f2e7e0a31.png)

# %% [markdown]
# ### KIC 5264818 / TIC 121732964 : okay both primary (~ 1.6% depth) and secondary (~ 1.6% depth)
#
# Paper: (x, time-span: ~1300 d ; y, O-C in kilosecs. Amplitude ~300s, or 5min)
#
# ![image.png](attachment:c37ecab0-fac6-4eb1-949a-73ea090b1642.png)
#
# Reproduction (Kepler data):
#
# ![image.png](attachment:3ec92156-1129-4cc8-a75a-d814b4b174c3.png)
#
# Reproduction (TESS data, much shoter time span, using the model from Kepler data): inconclusive.
# - The amplitude of variation seems to be larger. Unclear if it's periodic.
#
# ![image.png](attachment:5f551f2f-71d3-4b58-8e7e-3869f1b0cc2e.png)
#
# - Re-fitting TESS data using initial model params from TESS data (not shown here) the ampltiude appears to be slightly smaller.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## TTVs in `2019AJ....158..243P`
#
# [A Search for Multiplanet Systems with TESS Using a Bayesian N-body Retrieval and Machine Learning](https://ui.adsabs.harvard.edu/abs/2019AJ....158..243P/abstract)
#
# - Targets all have fairly U-shaped dips, with depth <= ~1%
# - based on TESS sectors 1 - 3 data

# %% [markdown]
# ### WASP-18 / TIC 100100827 : okay
#
# Paper:
#
# ![image.png](attachment:7ea2fbe5-effa-46e0-a741-0e78c231efc9.png)
#
# Reproduction:
#
# ![image.png](attachment:9b122c9c-bb21-4ef6-8f34-34daaa9c8c1e.png)

# %% [markdown]
# ### WASP-126 / TIC 25155310 : okay
#
#
# Paper:
#
# ![image.png](attachment:fd5c6ffc-1070-4d05-b7dc-3bdb726a1184.png)
#
# Reproduction:
#
# ![image.png](attachment:ed414d1d-98bd-4039-9753-8d347040fedd.png)
